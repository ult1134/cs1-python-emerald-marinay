# %% [markdown]
# <a href="https://colab.research.google.com/github/ult1134/cs1-python-emerald-marinay/blob/main/greaternum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter third number: "))

if num1 > num2 > num3:
  print(num1,"is greatest")
if num1 > num3 > num2:
  print(num1,"is greatest")
if num2 > num1 > num3:
  print(num2,"is greatest")
if num2 > num3 > num1:
  print(num2,"is greatest")
if num3 > num1 > num2:
  print(num3,"is greatest")
if num3 > num2 > num1:
  print(num3,"is greatest")
# Out:
# Enter first number: 5
# Enter second number: 2
# Enter third number: 4
# 5 is greatest
